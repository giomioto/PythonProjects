# %%
# !pip install pyautogui

# %%
import pyautogui
import time

pyautogui.PAUSE = 1
pyautogui.hotkey("ctrl","t")
pyautogui.write("pages.hashtagtreinamentos.com/aula1-intensivao-sistema/")
pyautogui.hotkey("enter")

time.sleep(5)
pyautogui.click(x=964, y=370)
pyautogui.write("meulogin")
pyautogui.click(x=993, y=449)
pyautogui.write("minhasenha")
pyautogui.click(x=1041, y=523)
time.sleep(5)
pyautogui.click(x=466, y=406)
pyautogui.click(x=734, y=201)
pyautogui.click(x=785, y=568)
time.sleep(3)
pyautogui.click(x=767, y=541)

# %%
import pandas
from pylab import *
from numpy import *

tabela = pandas.read_csv(r"C:\Users\giova\Downloads\Compras.csv", sep=";")
display(tabela)
total_gasto = tabela["ValorFinal"].sum()
quantidade = tabela["Quantidade"].sum()
preco_medio = total_gasto/quantidade
print(total_gasto)
print(quantidade)
print(preco_medio)
# Out:
#       CódigoCompra        Data               Fornecedor  \
# 0            65014  01/12/2023   Fabrica Hashtag Brasil
# 1            65014  01/12/2023   Fabrica Hashtag Brasil
# 2            65016  01/12/2023   Fabrica Doidona Brasil
# 3            65016  01/12/2023   Fabrica Doidona Brasil
# 4            65017  01/12/2023  Original Fábrica Brasil
# ...            ...         ...                      ...
# 4538         69996  26/12/2023        Revenda Argentina
# 4539         69996  26/12/2023        Revenda Argentina
# 4540         69996  26/12/2023        Revenda Argentina
# 4541         69997  26/12/2023   Fabrica Doidona Mexico
# 4542         69997  26/12/2023   Fabrica Doidona Mexico
#
#                             Produto  Quantidade  ValorUnitário  ValorFinal
# 0              Óleo Motor - Linha A           5         259.00     1295.00
# 1           Kit Embreagem - Linha A           1         380.00      380.00
# ...

# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1
pyautogui.hotkey("ctrl","t")
pyautogui.write("https://mail.google.com/mail/u/0/#inbox")
pyautogui.hotkey("enter")

time.sleep(5)

assunto = "Relatório de custos"
texto = f"""
Segue o relatório de custos da empresa
total gasto: {total_gasto:,.2f}
quantidade de produtos: {quantidade}
preço médio: {preco_medio:,.2f}
"""

pyautogui.click(x=131, y=185)
pyautogui.write("giovannimioto@ufpr.br")
pyautogui.hotkey("enter")
pyautogui.hotkey("tab")
pyperclip.copy(assunto)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")
pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")
